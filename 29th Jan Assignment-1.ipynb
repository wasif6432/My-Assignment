# %% [markdown]
# 29th Jan Assignment-1
#
# only answers are written:--
#
# 1) Python programming language was developed by Guido van Rossum.
#
# 2) Python is a versatile programming language that supports multiple programming :
#     a) Imperative programming
#     b) Procedural programming
#     c) object-oriented programming(oop)
#     d) fuctional programming
#     e) scripting
#     f) dynamic programming
#     g) Meta programming
#     h) Event-driven programming
#     i) web development
#     j) game development
#
# 3) Yes, Python is case-sensitive when it comes to identifiers.
#
# 4) The correct extension for Python source code files is ".py."
#
# 5) Python is typically considered an interpreted programming language.
#
# 6) a) Function (Def)
#    b) Conditional Statements (if, elif, else)
#    c) Loops (for and while)
#    d) Classes and Methods (Object-Oriented Programming)
#    e) Try-Except Blocks (Error Handling)
#
# 7) In Python, you can use the hash symbol (#) to create single-line comments.
#
# 8) python ---version
#
# 9) Python supports the creation of anonymous functions at runtime using a construct called "lambda" functions.
#
# 10) "pip"  stands for "Pip Installs Packages" or "Pip Installs Python."
#
# 11) print() , type(), len(), sum(), int(), float(), insert(), sorted(), count().
#
# 12)  the maximum possible length of an identifier is not explicitly defined by the language specification.
#
# 13) There are several benefits to using Python in various application domains:
#     Readability and Simplicity, Large Standard Library, Cross-Platform Compatibility, Community and Support, Open Source and Free,
#
# 14) Memory management in Python is primarily managed by the Python memory manager, which automates the process of allocating and deallocating memory for objects in your Python program.
#
# 15) first we will Download Python, then Run the Installer, then Customize Installation (Optional) then, Complete the Installation then, Verify Installation then, Set Up Path Variables :
#
#     If you forgot to check the "Add Python to PATH" option during installation, or if you need to set up path variables manually for some reason, follow these steps:
#
#     a. Open the Start menu and search for "Environment Variables."
#
#     b. Click on "Edit the system environment variables." In the System Properties window, click the "Environment Variables" button.
#
#     c. Under "System variables," scroll down and find the "Path" variable. Select it and click "Edit."
#
#     d. Click "New" and add the path to the Python installation directory. The default installation path is usually      C:\Users\<Your Username>\AppData\Local\Programs\Python\Python3x (where "3x" is the version number).
#
#     e. Click "OK" to close the windows.
#
# 16) yes
